# %%
import pandas as pd

data = pd.read_csv('MockPatientDatabaseOscar.csv', sep=';', header=0, encoding='ISO-8859-1')
data.head()
# Out:
#    Numero_paciente Genero   IMC Regimenafiliacion Anemia Hipercalcemia  \
# 0             1001      F  21,3      Contributivo     NO            NO
# 1             1002      F  24,4        Subsidiado     NO            NO
# 2             1003      M  21,8      Contributivo     NO            NO
# 3             1004      F  26,2      Contributivo     NO            NO
# 4             1005      M  28,1      Contributivo     NO            NO
#
#   ERC_Leve ERC_moderada ERC_severa ERC_dialisis  ... AdherenciaTtoMM1Mto1  \
# 0       NO           NO         NO           SI  ...                 33.0
# 1       NO           NO         SI           NO  ...                 25.0
# 2       NO           SI         NO           NO  ...                  5.0
# 3       NO           SI         NO           NO  ...                 77.0
# 4       NO           SI         NO           NO  ...                  NaN
#
#   Oportunidadtratamiento Dias_suspendidos Dias_en_terapia  \
# ...
